# %%
# Data Scientist
# Data Analyst
# Business Analyst
# Data Engineer
# ML Engineer

# %% [markdown]
# # EDA
# - Exploratory Data Analysis

# %% [markdown]
# - It is exploartion of data.
# - It is the interview with the data.
# - It is the process to know more about the data.
# - It is the process to look at the data from different angles and perspectives.

# %% [markdown]
# # Steps of EDA

# %% [markdown]
# - There are no specific steps for EDA.
# - It depends upon the problem or what insights we want to draw from the data.
# - Still there are a few steps that we follow with any kind of data that we are handling.
# - After following those steps we can have some good understanding about the data.

# %%
# - We check the size of the data (Shape of the data)
# - We check the attributes (columns) in the data.
# - We check the 5 point statistical summary of the data.
# - We check for the null values in the data
# - Treat the null values if present
# - We check for the duplicates
# - Treat the duplicate values if present
# - We check for the outliers
# - Treat the outliers if present
# - We check the data distribution
# - Analysis (Depending upon the insights we want to draw)

# %% [markdown]
# # Importing Librraies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing the dataset

# %%
data=pd.read_csv(r"loan_data.csv")
data.head()
# Out:
#         ID Amount.Requested Amount.Funded.By.Investors Interest.Rate  \
# 0  79542.0            25000                      25000        18.49%
# 1  75473.0            19750                      19750        17.27%
# 2  67265.0             2100                       2100        14.33%
# 3  80167.0            28000                      28000        16.29%
# 4  17240.0            24250                   17431.82        12.23%
#
#   Loan.Length        Loan.Purpose Debt.To.Income.Ratio State Home.Ownership  \
# 0   60 months  debt_consolidation               27.56%    VA       MORTGAGE
# 1   60 months  debt_consolidation               13.39%    NY       MORTGAGE
# 2   36 months      major_purchase                3.50%    LA            OWN
# 3   36 months         credit_card               19.62%    NV       MORTGAGE
# 4   60 months         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly.Income FICO.Range Open.CREDIT.Lines Revolving.CREDIT.Balance  \
# ...

# %% [markdown]
# # Size of the data

# %%
data.shape
# Out:
# (2200, 15)

# %%
# 2200 rows and 15 columns

# %% [markdown]
# # Columns in the data

# %%
data.columns
# Out:
# Index(['ID', 'Amount.Requested', 'Amount.Funded.By.Investors', 'Interest.Rate',
#        'Loan.Length', 'Loan.Purpose', 'Debt.To.Income.Ratio', 'State',
#        'Home.Ownership', 'Monthly.Income', 'FICO.Range', 'Open.CREDIT.Lines',
#        'Revolving.CREDIT.Balance', 'Inquiries.in.the.Last.6.Months',
#        'Employment.Length'],
#       dtype='object')

# %% [markdown]
# # Replacing . with _ in the column names

# %%
data.columns=data.columns.str.replace('.','_')

# %%
data.columns
# Out:
# Index(['ID', 'Amount_Requested', 'Amount_Funded_By_Investors', 'Interest_Rate',
#        'Loan_Length', 'Loan_Purpose', 'Debt_To_Income_Ratio', 'State',
#        'Home_Ownership', 'Monthly_Income', 'FICO_Range', 'Open_CREDIT_Lines',
#        'Revolving_CREDIT_Balance', 'Inquiries_in_the_Last_6_Months',
#        'Employment_Length'],
#       dtype='object')

# %%
data.head()
# Out:
#         ID Amount_Requested Amount_Funded_By_Investors Interest_Rate  \
# 0  79542.0            25000                      25000        18.49%
# 1  75473.0            19750                      19750        17.27%
# 2  67265.0             2100                       2100        14.33%
# 3  80167.0            28000                      28000        16.29%
# 4  17240.0            24250                   17431.82        12.23%
#
#   Loan_Length        Loan_Purpose Debt_To_Income_Ratio State Home_Ownership  \
# 0   60 months  debt_consolidation               27.56%    VA       MORTGAGE
# 1   60 months  debt_consolidation               13.39%    NY       MORTGAGE
# 2   36 months      major_purchase                3.50%    LA            OWN
# 3   36 months         credit_card               19.62%    NV       MORTGAGE
# 4   60 months         credit_card               23.79%    OH       MORTGAGE
#
#    Monthly_Income FICO_Range Open_CREDIT_Lines Revolving_CREDIT_Balance  \
# ...

# %%
# data.Amount_Funded_By_Investors

# %% [markdown]
# # Basic information of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ID                              2199 non-null   float64
#  1   Amount_Requested                2199 non-null   object
#  2   Amount_Funded_By_Investors      2199 non-null   object
#  3   Interest_Rate                   2200 non-null   object
#  4   Loan_Length                     2199 non-null   object
#  5   Loan_Purpose                    2199 non-null   object
#  6   Debt_To_Income_Ratio            2199 non-null   object
#  7   State                           2199 non-null   object
#  8   Home_Ownership                  2199 non-null   object
#  9   Monthly_Income                  2197 non-null   float64
#  10  FICO_Range                      2200 non-null   object
#  11  Open_CREDIT_Lines               2196 non-null   object
# ...

# %%
# Amount Requested - Convert to Numeric
# Amount_Funded_By_Investors- Convert to Numeric
# Interest_Rate- Convert to Numeric
# Interest_Rate- Convert to Numeric
# Debt_To_Income_Ratio- Convert to Numeric
# FICO_Range- Convert to Numeric
# Revolving_CREDIT_Balance- Convert to Numeric
# Revolving_CREDIT_Balance- Convert to Numeric

# %% [markdown]
# # Conversion to Numeric

# %% [markdown]
# ### 1-Amount_Requested

# %%
# data.Amount_Requested.astype(int)

# %%
# data[~(data.Amount_Requested=='.')]['Amount_Requested'].astype(float)

# %%
# int(np.nan)

# %%
data[(data.Amount_Requested=='.')]
# Out:
#             ID Amount_Requested Amount_Funded_By_Investors Interest_Rate  \
# 371   101798.0                .                       1850        12.49%
# 1357   71249.0                .                      12000        10.16%
# 1791   68628.0                .                      15875        14.33%
# 1991   15867.0                .                       7000         6.91%
#
#      Loan_Length        Loan_Purpose Debt_To_Income_Ratio State  \
# 371    36 months    home_improvement               20.56%    MD
# 1357   36 months  debt_consolidation               27.48%    VA
# 1791   36 months      small_business               17.44%    MD
# 1991   36 months         credit_card                7.10%    CA
#
#      Home_Ownership  Monthly_Income FICO_Range Open_CREDIT_Lines  \
# 371        MORTGAGE         3448.33    660-664                10
# 1357       MORTGAGE         5000.00    710-714                12
# 1791       MORTGAGE         3416.67    675-679                11
# ...

# %%
data.Amount_Requested.isna().sum()
# Out:
# np.int64(1)

# %%
data.Amount_Requested=pd.to_numeric(data.Amount_Requested,errors='coerce')

# %%
data.Amount_Requested.isna().sum()
# Out:
# np.int64(5)

# %%
data.iloc[[371,1357,1791,1991]]
# Out:
#             ID  Amount_Requested Amount_Funded_By_Investors Interest_Rate  \
# 371   101798.0               NaN                       1850        12.49%
# 1357   71249.0               NaN                      12000        10.16%
# 1791   68628.0               NaN                      15875        14.33%
# 1991   15867.0               NaN                       7000         6.91%
#
#      Loan_Length        Loan_Purpose Debt_To_Income_Ratio State  \
# 371    36 months    home_improvement               20.56%    MD
# 1357   36 months  debt_consolidation               27.48%    VA
# 1791   36 months      small_business               17.44%    MD
# 1991   36 months         credit_card                7.10%    CA
#
#      Home_Ownership  Monthly_Income FICO_Range Open_CREDIT_Lines  \
# 371        MORTGAGE         3448.33    660-664                10
# 1357       MORTGAGE         5000.00    710-714                12
# 1791       MORTGAGE         3416.67    675-679                11
# ...

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors         object
# Interest_Rate                      object
# Loan_Length                        object
# Loan_Purpose                       object
# Debt_To_Income_Ratio               object
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 2- Amount_Funded_By_Investors

# %%
data.Amount_Funded_By_Investors
# Out:
# 0          25000
# 1          19750
# 2           2100
# 3          28000
# 4       17431.82
#           ...
# 2195       30000
# 2196        4200
# 2197       19775
# 2198       18000
# 2199        7550
# Name: Amount_Funded_By_Investors, Length: 2200, dtype: object

# %%
data['Amount_Funded_By_Investors']
# Out:
# 0          25000
# 1          19750
# 2           2100
# 3          28000
# 4       17431.82
#           ...
# 2195       30000
# 2196        4200
# 2197       19775
# 2198       18000
# 2199        7550
# Name: Amount_Funded_By_Investors, Length: 2200, dtype: object

# %%
data[['Amount_Funded_By_Investors']]
# Out:
#      Amount_Funded_By_Investors
# 0                         25000
# 1                         19750
# 2                          2100
# 3                         28000
# 4                      17431.82
# ...                         ...
# 2195                      30000
# 2196                       4200
# 2197                      19775
# 2198                      18000
# 2199                       7550
#
# [2200 rows x 1 columns]

# %%
#data.Amount_Funded_By_Investors.astype(float)

# %%
#data[data.Amount_Funded_By_Investors == '.']

# %%
data.loc[data.Amount_Funded_By_Investors=='.','Amount_Funded_By_Investors']=np.nan

# %%
data.Amount_Funded_By_Investors=data.Amount_Funded_By_Investors.astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                      object
# Loan_Length                        object
# Loan_Purpose                       object
# Debt_To_Income_Ratio               object
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 3- Interest Rate

# %%
data.Interest_Rate
# Out:
# 0       18.49%
# 1       17.27%
# 2       14.33%
# 3       16.29%
# 4       12.23%
#          ...
# 2195    23.28%
# 2196    14.33%
# 2197    15.31%
# 2198    20.99%
# 2199    10.16%
# Name: Interest_Rate, Length: 2200, dtype: object

# %%
data.Interest_Rate=data.Interest_Rate.str.strip('%').astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                        object
# Loan_Purpose                       object
# Debt_To_Income_Ratio               object
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 4- Loan_Length

# %%
data.Loan_Length
# Out:
# 0       60 months
# 1       60 months
# 2       36 months
# 3       36 months
# 4       60 months
#           ...
# 2195    60 months
# 2196    60 months
# 2197    60 months
# 2198    60 months
# 2199    36 months
# Name: Loan_Length, Length: 2200, dtype: object

# %%
data.Loan_Length.unique()
# Out:
# array(['60 months', '36 months', nan, '.'], dtype=object)

# %%
data.loc[data.Loan_Length=='.','Loan_Length']=np.nan

# %%
data.Loan_Length.unique()
# Out:
# array(['60 months', '36 months', nan], dtype=object)

# %%
data.Loan_Length=data.Loan_Length.replace(r'[a-z ]+','',regex=True).astype(float) # (r'[a-z ]+','',regex=True) is a regex pattern

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio               object
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 5- Debt_To_Income_Ratio

# %%
data.Debt_To_Income_Ratio
# Out:
# 0       27.56
# 1       13.39
# 2        3.50
# 3       19.62
# 4       23.79
#         ...
# 2195    12.10
# 2196    14.16
# 2197    15.03
# 2198    11.63
# 2199     3.83
# Name: Debt_To_Income_Ratio, Length: 2200, dtype: float64

# %%
#pd.to_numeric(data.Debt_To_Income_Ratio,errors = 'çoerce')

# %%
data.Debt_To_Income_Ratio=data.Debt_To_Income_Ratio.replace(r'%','',regex=True).astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                         object
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 6- FICO Range

# %%
data.FICO_Range
# Out:
# 0       720-724
# 1       710-714
# 2       690-694
# 3       710-714
# 4       730-734
#          ...
# 2195    675-679
# 2196    700-704
# 2197    675-679
# 2198    670-674
# 2199    710-714
# Name: FICO_Range, Length: 2200, dtype: object

# %%
fico=data.FICO_Range.str.split('-',expand=True).astype(int) # expand = True converting into two column
fico.columns=['Min','Max']
fico.head()
# Out:
#    Min  Max
# 0  720  724
# 1  710  714
# 2  690  694
# 3  710  714
# 4  730  734

# %%
fico.dtypes
# Out:
# Min    int64
# Max    int64
# dtype: object

# %%
(fico.Max+fico.Min)/2
# Out:
# 0       722.0
# 1       712.0
# 2       692.0
# 3       712.0
# 4       732.0
#         ...
# 2195    677.0
# 2196    702.0
# 2197    677.0
# 2198    672.0
# 2199    712.0
# Length: 2200, dtype: float64

# %%
data.FICO_Range=(fico.Max+fico.Min)/2

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                        float64
# Open_CREDIT_Lines                  object
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %%
data.head()
# Out:
#         ID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 0  79542.0           25000.0                    25000.00          18.49
# 1  75473.0           19750.0                    19750.00          17.27
# 2  67265.0            2100.0                     2100.00          14.33
# 3  80167.0           28000.0                    28000.00          16.29
# 4  17240.0           24250.0                    17431.82          12.23
#
#    Loan_Length        Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 0         60.0  debt_consolidation                 27.56    VA       MORTGAGE
# 1         60.0  debt_consolidation                 13.39    NY       MORTGAGE
# 2         36.0      major_purchase                  3.50    LA            OWN
# 3         36.0         credit_card                 19.62    NV       MORTGAGE
# 4         60.0         credit_card                 23.79    OH       MORTGAGE
#
# ...

# %% [markdown]
# ### 7- Open_Credit_Lines

# %%
# data.Open_CREDIT_Lines.astype(float)

# %%
data[data.Open_CREDIT_Lines=='.']
# Out:
#            ID  Amount_Requested  Amount_Funded_By_Investors  Interest_Rate  \
# 98    65134.0           34500.0                     34450.0           6.62
# 1383  66424.0            9050.0                      9050.0          13.11
# 1907  68850.0            3000.0                      2975.0           7.90
#
#       Loan_Length    Loan_Purpose  Debt_To_Income_Ratio State Home_Ownership  \
# 98           36.0  small_business                 16.46    CA       MORTGAGE
# 1383         36.0     credit_card                 20.58    MI       MORTGAGE
# 1907         36.0  major_purchase                 17.58    LA           RENT
#
#       Monthly_Income  FICO_Range Open_CREDIT_Lines Revolving_CREDIT_Balance  \
# 98          10000.00       807.0                 .                     5317
# 1383         5166.67       702.0                 .                     7571
# 1907         3458.33       722.0                 .                     2999
#
# ...

# %%
data.loc[data.Open_CREDIT_Lines=='.','Open_CREDIT_Lines']=np.nan

# %%
data.Open_CREDIT_Lines=data.Open_CREDIT_Lines.astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                        float64
# Open_CREDIT_Lines                 float64
# Revolving_CREDIT_Balance           object
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 8- Revolving_CREDIT_Balance

# %%
# data.Revolving_CREDIT_Balance.astype(float)

# %%
data.loc[data.Revolving_CREDIT_Balance=='.','Revolving_CREDIT_Balance']=np.nan

# %%
data.Revolving_CREDIT_Balance=data.Revolving_CREDIT_Balance.astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                        float64
# Open_CREDIT_Lines                 float64
# Revolving_CREDIT_Balance          float64
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                  object
# dtype: object

# %% [markdown]
# ### 9- Employment_Length

# %%
data.Employment_Length.unique()
# Out:
# array(['5 years', '4 years', '< 1 year', '10+ years', nan, '2 years',
#        '8 years', '1 year', '6 years', '7 years', '3 years', '9 years',
#        '.'], dtype=object)

# %%
data.loc[data.Employment_Length=='.','Employment_Length']=np.nan

# %%
data.Employment_Length=data.Employment_Length.replace(r'[a-z <+]','',regex=True).astype(float)

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                        float64
# Open_CREDIT_Lines                 float64
# Revolving_CREDIT_Balance          float64
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                 float64
# dtype: object

# %%
#float(np.nan)

# %% [markdown]
# # Check for the missing values

# %%
data.isna().sum()
# Out:
# ID                                 1
# Amount_Requested                   5
# Amount_Funded_By_Investors         4
# Interest_Rate                      0
# Loan_Length                        2
# Loan_Purpose                       1
# Debt_To_Income_Ratio               1
# State                              1
# Home_Ownership                     1
# Monthly_Income                     3
# FICO_Range                         0
# Open_CREDIT_Lines                  7
# Revolving_CREDIT_Balance           5
# Inquiries_in_the_Last_6_Months     3
# Employment_Length                 70
# dtype: int64

# %% [markdown]
# # Imputation of the missing values

# %%
# Generally in a Numeric continuous column we fill the missing values with mean or median
# In categorical column we fill with mode

# %%
data.nunique()
# Out:
# ID                                2199
# Amount_Requested                   355
# Amount_Funded_By_Investors         657
# Interest_Rate                      265
# Loan_Length                          2
# Loan_Purpose                        14
# Debt_To_Income_Ratio              1526
# State                               46
# Home_Ownership                       5
# Monthly_Income                     581
# FICO_Range                          38
# Open_CREDIT_Lines                   28
# Revolving_CREDIT_Balance          2079
# Inquiries_in_the_Last_6_Months      10
# Employment_Length                   10
# dtype: int64

# %%
num_cols=[]
cat_cols=[]

for i in data.columns:
    if data[i].nunique()>5 and data[i].dtype==float or data[i].dtype==int:
        num_cols.append(i)
    else:
        cat_cols.append(i)

# %%
num_cols
# Out:
# ['ID',
#  'Amount_Requested',
#  'Amount_Funded_By_Investors',
#  'Interest_Rate',
#  'Debt_To_Income_Ratio',
#  'Monthly_Income',
#  'FICO_Range',
#  'Open_CREDIT_Lines',
#  'Revolving_CREDIT_Balance',
#  'Inquiries_in_the_Last_6_Months',
#  'Employment_Length']

# %%
cat_cols
# Out:
# ['Loan_Length', 'Loan_Purpose', 'State', 'Home_Ownership']

# %%
def null_impute_numeric(col):
    data[col].fillna(data[col].mean(),inplace=True)

# %%
def null_impute_cat(col):
    data[col].fillna(data[col].mode()[0],inplace=True)

# %%
data.isna().sum()
# Out:
# ID                                 1
# Amount_Requested                   5
# Amount_Funded_By_Investors         4
# Interest_Rate                      0
# Loan_Length                        2
# Loan_Purpose                       1
# Debt_To_Income_Ratio               1
# State                              1
# Home_Ownership                     1
# Monthly_Income                     3
# FICO_Range                         0
# Open_CREDIT_Lines                  7
# Revolving_CREDIT_Balance           5
# Inquiries_in_the_Last_6_Months     3
# Employment_Length                 70
# dtype: int64

# %%
for i in num_cols:
    null_impute_numeric(i)

# %%
data.isna().sum()
# Out:
# ID                                0
# Amount_Requested                  0
# Amount_Funded_By_Investors        0
# Interest_Rate                     0
# Loan_Length                       2
# Loan_Purpose                      1
# Debt_To_Income_Ratio              0
# State                             1
# Home_Ownership                    1
# Monthly_Income                    0
# FICO_Range                        0
# Open_CREDIT_Lines                 0
# Revolving_CREDIT_Balance          0
# Inquiries_in_the_Last_6_Months    0
# Employment_Length                 0
# dtype: int64

# %%
for i in cat_cols:
    null_impute_cat(i)

# %%
data.isna().sum()
# Out:
# ID                                0
# Amount_Requested                  0
# Amount_Funded_By_Investors        0
# Interest_Rate                     0
# Loan_Length                       0
# Loan_Purpose                      0
# Debt_To_Income_Ratio              0
# State                             0
# Home_Ownership                    0
# Monthly_Income                    0
# FICO_Range                        0
# Open_CREDIT_Lines                 0
# Revolving_CREDIT_Balance          0
# Inquiries_in_the_Last_6_Months    0
# Employment_Length                 0
# dtype: int64

# %% [markdown]
# # Check for the outliers : Only for numerical column

# %%
sns.set_theme(style='whitegrid',palette='bright',font='cursive',font_scale=1.2)

# %%
#sns.boxplot(data = data)

# %%
data.plot(kind='box',figsize=(18,12))
plt.xticks(rotation=45)
plt.show()

# %%
# help(data.plot)

# %%
num_cols
# Out:
# ['ID',
#  'Amount_Requested',
#  'Amount_Funded_By_Investors',
#  'Interest_Rate',
#  'Debt_To_Income_Ratio',
#  'Monthly_Income',
#  'FICO_Range',
#  'Open_CREDIT_Lines',
#  'Revolving_CREDIT_Balance',
#  'Inquiries_in_the_Last_6_Months',
#  'Employment_Length']

# %%
f,ax=plt.subplots(3,4,figsize=(18,15),dpi=100)
ind=0
try:
    for i in range(3):
        for j in range(4):
            ax[i,j].boxplot(data[num_cols[ind]])
            ind+=1
        plt.tight_layout()
except:
    pass
plt.show()

# %%
num_cols[10]
# Out:
# 'Employment_Length'

# %%
f,ax=plt.subplots(3,4,figsize=(18,15),dpi=100)
ind=0
try:
    for i in range(3):
        for j in range(4):
            sns.boxplot(data[num_cols[ind]],ax=ax[i,j])
            ax[i,j].set_title(num_cols[ind])
            ind+=1
        plt.tight_layout()
except:
    pass
plt.show()

# %%
len(num_cols)
# Out:
# 11

# %%
f,ax=plt.subplots(3,4)
ind=0
try:
    for i in range(3):
        for j in range(4):
            ax[i,j].boxplot(data[num_cols[ind]])
            ax[i,j].set_title(num_cols[ind])
            ind+=1
            plt.tight_layout()
except:
    pass
plt.show()

# %%
ind=3
sns.boxplot(data[num_cols[ind]])
plt.title(num_cols[ind])
# Out:
# Text(0.5, 1.0, 'Interest_Rate')

# %%
data.dtypes
# Out:
# ID                                float64
# Amount_Requested                  float64
# Amount_Funded_By_Investors        float64
# Interest_Rate                     float64
# Loan_Length                       float64
# Loan_Purpose                       object
# Debt_To_Income_Ratio              float64
# State                              object
# Home_Ownership                     object
# Monthly_Income                    float64
# FICO_Range                        float64
# Open_CREDIT_Lines                 float64
# Revolving_CREDIT_Balance          float64
# Inquiries_in_the_Last_6_Months    float64
# Employment_Length                 float64
# dtype: object
